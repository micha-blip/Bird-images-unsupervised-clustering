# %% [markdown]
# <a href="https://colab.research.google.com/github/micha-blip/Bird-images-unsupervised-clustering/blob/main/Reference_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import numpy as np
import pandas as pd

# this is a simple function which takes DOI, extracts references and checks if those articles actually exist
# made to be used as a simple weapon against LLM - hallucinated references
# it takes DOI as for example 10.1016/j.cell.2025.08.007
# in the output
#   green means reference was found
#   red means reference was not found
#   yellow means DOI of the reference is missing

def get_references_from_doi(doi, return_dataframe = True):

  api_url = f"https://api.crossref.org/v1/works/{doi}"
  headers = {"User-Agent": "SimpleFetcher"}
  print('Sending request...')

  try:
      response = requests.get(api_url, headers=headers)
      response.raise_for_status()  # Check for bad responses
      data = response.json()

      # Get the list of references from the response
      references = data["message"].get("reference", [])
      title = data["message"].get('title', [])
      title = str(title[0]).replace("\\n", " ").replace('<sup>+</sup>', "")
      print('Processing response for: ' + '\x1B[3m'  + title)

      doi_list = []

      if references:
          for i, ref in enumerate(references):
              ref_key = ref.get('key', f"substitute_key_{i}") # Use a substitute key if 'key' is missing
              # The 'unstructured' field often contains the full reference string
              if "DOI" in ref:
                  doi_list.append(ref['DOI'])
              elif "unstructured" in ref:
                  doi_list.append('not found')
              else:
                  doi_list.append('not found')

  except requests.exceptions.RequestException as e:
      print(f"An error occurred: The article was not found")
      return

  check_status = check_references_for_doi(doi_list)

  print("Done, found " + str(sum(check_status == "article found")) + " existing documents, " + str(sum(check_status == "no article")) + " non-existing documents" + " and " + str(sum(check_status == 'no DOI')) + " missing DOI")

  if return_dataframe == True:
    references_checked = pd.DataFrame(doi_list,  columns=['DOI'])
    references_checked['status'] = check_status
    return references_checked



def check_references_for_doi(doi_list):
  headers = {"User-Agent": "SimpleFetcher"}
  status = np.full(len(doi_list), "not processed")

  for i, doi in enumerate(doi_list):
    api_url = f"https://api.crossref.org/v1/works/{doi}"
    if doi == 'not found': # if there is no doi
      status[i] = 'no DOI'
      print('\033[33m' + str(i+1) +" " +  "DOI missing" + '\033[0m')
      continue
    try:
        response = requests.get(api_url, headers=headers)
        response.raise_for_status()
        data = response.json()
        print('\033[32m'  + str(i+1) + " " + data["message"].get("title", ["No Title Available"])[0] + '\033[0m')
        status[i] = "article found"
    except requests.exceptions.RequestException as e:
        print('\033[31m' + str(i+1) + " " +  f"Error fetching data for " + data["message"].get("title", ["No Title Available"])[0] + '\033[0m')
        status[i] = 'no article'
  return status

# %%
x = get_references_from_doi(doi =  '10.1093/jas/skaf174', return_dataframe=True )
# Out:
# Sending request...
# Processing response for: Changes of fecal microbiota with supplementation of <i>Acremonium terricola</i> culture and yeast culture in ewes during lactation
# 1 Effect of supplementing live Saccharomyces cerevisiae yeast on performance, rumen function, and metabolism during the transition period in Holstein dairy cows
# 2 Proteomics and metabolomics characterizing the pathophysiology of adaptive reactions to the metabolic challenges during the transition from late pregnancy to early lactation in dairy cows
# 3 Glycine, serine and threonine metabolism confounds efficacy of complement-mediated killing
# 4 Re-print of “Intestinal luminal nitrogen metabolism: Role of the gut microbiota and consequences for the host”
# 5 Utilizing the fecal microbiota to understand foal gut transitions from birth to weaning
# 6 Changes in rumen microbiota composition and in situ degradation kinetics during the dry period and early lactation as affected by rate of increase of concentrate allowance
# 7 Succinic acid production from wheat using a biorefining strategy
# 8 Changes in Digestive Microbiota, Rumen Fermentations and Oxidative Stress around Parturition Are Alleviated by Live Yeast Feed Supplementation to Gestating Ewes
# 9 O-164 Live yeast supplementation during last month of gestation improves ewes ruminal microbiota, oxidative status, colostrum quality and offspring immune competence
# 10 β-N-Methylamino-l-alanine (BMAA) perturbs alanine, aspartate and glutamate metabolism pathways in human neuroblastoma cells as determined by metabolic profiling
# 11 Characterization of Eubacterium coprostanoligenes sp. nov., a Cholesterol-Reducing Anaerobe
# 12 Comparison of rectum fecal bacterial community of finishing bulls fed high-concentrate diets with active dry yeast and yeast culture supplementation
# 13 Effects of Escherichia coli Nissle 1917 on the Porcine Gut Microbiota, Intestinal Epithelium and Immune System in Early Life
# 14 Review: Metabolic challenges in lactating dairy cows and their assessment via established and novel indicators in milk
# 15 Metagenomic Discovery of Biomass-Degrading Genes and Genomes from Cow Rumen
# 16 Dynamic changes of the fecal bacterial community in dairy cows during early lactation
# 17 Marked Seasonal Variation in Structure and Function of Gut Microbiota in Forest and Alpine Musk Deer
# 18 Stability of the Maternal Gut Microbiota During Late Pregnancy and Early Lactation
# 19 Effects of Cordyceps militaris on the growth of rumen microorganisms and in vitro rumen fermentation with respect to methane emissions
# 20 Acremonium terricola Culture’s Dose–Response Effects on Lactational Performance, Antioxidant Capacity, and Ruminal Characteristics in Holstein Dairy Cows
# 21 Obesity alters gut microbial ecology
# 22 Effects of Acremonium terricola culture supplementation on apparent digestibility, rumen fermentation, and blood parameters in dairy cows
# 23 Effects of Acremonium terricola culture on performance, milk composition, rumen fermentation and immune functions in dairy cows
# 24 Mixed silage with Chinese cabbage waste enhances antioxidant ability by increasing ascorbate and aldarate metabolism through rumen Prevotellaceae UCG-004 in Hu sheep
# 25 Effects of dry yeast supplementation on growth performance, rumen fermentation characteristics, slaughter performance and microbial communities in beef cattle
# 26 Review of yeast culture concerning the interactions between gut microbiota and young ruminant animals
# 27 The Bacterial and Fungal Microbiota of Nelore Steers Is Dynamic Across the Gastrointestinal Tract and Its Fecal-Associated Microbiota Is Correlated to Feed Efficiency
# 28 Characterising the bacterial microbiota across the gastrointestinal tracts of dairy cattle: membership and potential function
# 29 T cell–mediated regulation of the microbiota protects against obesity
# 30 87 Functional rumen microbiological survey of triplet-bearing Polypay ewes from parturition to weaning
# 31 Fecal bacterial community of finishing beef steers fed ruminally protected and non-protected active dried yeast
# 32 A novel enteropathogenic, strongly haemolytic spirochaete isolated from pig and mallard, provisionally designated ‘<i>Brachyspira suanatina</i>’ sp. nov.
# 33 Proteobacteria: microbial signature of dysbiosis in gut microbiota
# 34 Nicotinic acid and derivatives as multifunctional pharmacophores for medical applications
# 35 Regulation of Nutritional Metabolism in Transition Dairy Cows: Energy Homeostasis and Health in Response to Post-Ruminal Choline and Methionine
# 36 Dynamic Distribution of Gut Microbiota in Goats at Different Ages and Health States
# 37 Cordyceps guangdongensis lipid-lowering formula alleviates fat and lipid accumulation by modulating gut microbiota and short-chain fatty acids in high-fat diet mice
# 38 Yeast (Saccharomyces cerevisiae) Culture Promotes the Performance of Fattening Sheep by Enhancing Nutrients Digestibility and Rumen Development
# 39 Error fetching data for Yeast (Saccharomyces cerevisiae) Culture Promotes the Performance of Fattening Sheep by Enhancing Nutrients Digestibility and Rumen Development
# 40 Yeast culture repairs rumen epithelial injury by regulating microbial communities and metabolites in sheep
# 41 Dietary supplementation with Acremonium terricola culture alters the gut microbial structure and improves the growth performance, antioxidant status, and immune function of weaning piglets
# 42 Heritability and recursive influence of host genetics on the rumen microbiota drive body weight variance in male Hu sheep lambs
# 43 Fecal g. Streptococcus and g. Eubacterium_coprostanoligenes_group combined with sphingosine to modulate the serum dyslipidemia in high-fat diet mice
# 44 Assessment of Rumen Microbiota from a Large Dairy Cattle Cohort Reveals the Pan and Core Bacteriomes Contributing to Varied Phenotypes
# 45 The Dynamic Distribution of Small-Tail Han Sheep Microbiota across Different Intestinal Segments
# 46 Diaphragma juglandis extracts modifies the gut microbiota during prevention of type 2 diabetes in rats
# 47 Active dry yeast supplementation benefits ruminal fermentation, bacterial community, blood immunoglobulins, and growth performance in young dairy goats, but not for intermittent supplementation
# 48 Error fetching data for Active dry yeast supplementation benefits ruminal fermentation, bacterial community, blood immunoglobulins, and growth performance in young dairy goats, but not for intermittent supplementation
# 49 Enhanced Antioxidative Capacity Transfer between Sow and Fetus via the Gut–Placenta Axis with Dietary Selenium Yeast and Glycerol Monolaurate Supplementation during Pregnancy
# 50 Cordyceps militaris Modulates Intestinal Barrier Function and Gut Microbiota in a Pig Model
# 51 Changes in rumen bacterial and archaeal communities over the transition period in primiparous Holstein dairy cows
# Done, found 49 existing documents, 2 non-existing documents and 0 missing DOI

# %%
x
# Out:
#                                      DOI         status
# 0                 10.3168/jds.2022-23046  article found
# 1            10.1016/j.jprot.2017.10.010  article found
# 2             10.1038/s41467-019-11129-5  article found
# 3             10.1016/j.phrs.2013.01.003  article found
# 4           10.1371/journal.pone.0216211  article found
# 5                 10.3168/jds.2016-11982  article found
# 6              10.1007/s00253-007-1113-7  article found
# 7                     10.3390/jof7060447  article found
# 8           10.1016/j.anscip.2023.01.240  article found
# 9              10.1007/s00726-017-2391-8  article found
# 10             10.1099/00207713-44-1-137  article found
# 11                    10.5713/ab.22.0215  article found
# 12             10.3389/fmicb.2022.842437  article found
# 13             10.1017/S175173111800349X  article found
# 14               10.1126/science.1200387  article found
# 15            10.1186/s13568-020-01106-3  article found
# 16             10.3389/fmicb.2021.699797  article found
# 17             10.1007/s00284-013-0491-6  article found
# 18                 10.3168/jds.2014-8064  article found
# 19                10.3390/antiox11010175  article found
# 20               10.1073/pnas.0504978102  article found
# 21      10.1016/j.anifeedsci.2017.05.015  article found
# 22      10.1016/j.anifeedsci.2018.03.015  article found
# 23             10.3389/fmicb.2022.978940  article found
# 24         10.1080/10495398.2021.1878204  article found
# 25            10.3389/fvets.2024.1335765  article found
# 26              10.3389/fmicb.2019.01263  article found
# 27                     10.1038/srep16116  article found
# 28               10.1126/science.aat9351  article found
# 29               10.1093/jas/skae019.021  article found
# 30                   10.1093/jas/skaa058  article found
# 31      10.1111/j.1462-2920.2006.01220.x  article found
# 32         10.1016/j.tibtech.2015.06.011  article found
# 33             10.1007/s00217-014-2354-1  article found
# 34          10.1371/journal.pone.0160659  article found
# 35              10.3389/fmicb.2018.02509  article found
# 36             10.3389/fnut.2022.1038740  article found
# 37           10.3390/fermentation8120719  article found
# 38  10.3969/j.issn.1006-267x.2022.06.044     no article
# 39            10.3389/fmicb.2023.1305772  article found
# 40            10.1186/s12917-023-03778-y  article found
# 41            10.1186/s40168-023-01642-7  article found
# 42            10.1016/j.clnu.2021.01.031  article found
# 43                  10.1128/AEM.00970-18  article found
# 44              10.3389/fmicb.2018.00032  article found
# 45             10.1016/j.jep.2021.114484  article found
# 46           10.1016/j.aninu.2023.02.001  article found
# 47                 10.12418/CJAN2023.719     no article
# 48                10.3390/antiox13020141  article found
# 49             10.3389/fmicb.2022.810230  article found
# 50                10.3168/jds.2017-14366  article found
